# %%
import pandas as pd

# %%
st_path = '/Users/tsaim5/Documents/MATLAB/corr_table.csv'

# %%
df = pd.read_csv(st_path)

# %%
df.sample(10)
# Out:
#         row_id animal_id  T_series    expt_date surgery_date   birth_date  \
# 435251      91        m6         2  25-Apr-2019  18-Mar-2019  14-Oct-2018
# 26788        8        m1         6  26-Mar-2019  11-Mar-2019  01-Oct-2018
# 148990      24        m1         9  24-Apr-2019  11-Mar-2019  01-Oct-2018
# 286364      46        m4         1  25-Apr-2019  18-Mar-2019  23-Oct-2018
# 356669      67        m5         0  25-Apr-2019  18-Mar-2019  14-Oct-2018
# 374605      72        m5         1  07-May-2019  18-Mar-2019  14-Oct-2018
# 199874      30        m1        13  06-May-2019  11-Mar-2019  01-Oct-2018
# 269911      37        m4         0  28-Mar-2019  18-Mar-2019  08-Nov-2018
# 97691       19        m1         6  24-Apr-2019  11-Mar-2019  01-Oct-2018
# 83184       16        m1         5  02-Apr-2019  11-Mar-2019  01-Oct-2018
#
#         age  days_post_surgery colony_id  \
# 435251    8                  5  8615-630
# 26788     5                  2  8615-624
# ...
